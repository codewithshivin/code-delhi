# %%
import json

# %%
# A function to load data
def get_data(filename):
    with open(filename, "r") as f:
        data = json.load(f)
    return data

# %%
data = get_data("codeconnect.json")

# %%
data
# Out:
# {'users': [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]},
#   {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]},
#   {'id': 3, 'name': 'Rahul', 'friends': [1], 'liked_pages': [101, 103]},
#   {'id': 4, 'name': 'Sara', 'friends': [2], 'liked_pages': [104]}],
#  'pages': [{'id': 101, 'name': 'Python Developers'},
#   {'id': 102, 'name': 'Data Science Enthusiasts'},
#   {'id': 103, 'name': 'AI & ML Community'},
#   {'id': 104, 'name': 'Web Dev Hub'}]}

# %%
type(data)
# Out:
# dict

# %%
# A function to get user connection and their intrest
"""def user_info(data):
    print("User and their connection\n")
    for user in data['users']:
        print(f"{user['name']} is friend with {user['friends']} and their intrest is {user['liked_pages']}")
    print("Pages information")
    for page in data ['pages']:
        print(f"{page['id']}:{page['name']}")

user_info(data)
# Out:
# User and their connection
#
# Amit is friend with [2, 3] and their intrest is [101]
# Priya is friend with [1, 4] and their intrest is [102]
# Rahul is friend with [1] and their intrest is [101, 103]
# Sara is friend with [2] and their intrest is [104]
# Pages information
# 101:Python Developers
# 102:Data Science Enthusiasts
# 103:AI & ML Community
# 104:Web Dev Hub

# %%
# Out:
# User and their connection
#
# Amit is friend with [2, 3] and their intrest is [101]
# Priya is friend with [1, 4] and their intrest is [102]
# Rahul is friend with [1] and their intrest is [101, 103]
# Sara is friend with [2] and their intrest is [104]
# Pages information
# 101:Python Developers
# 102:Data Science Enthusiasts
# 103:AI & ML Community
# 104:Web Dev Hub

# %%
# making look more presentable
def user_info(data):
    print("User and their connection\n")
    for user in data['users']:
        print(f"{user['id']}:{user['name']} is friend with {user['friends']} and their intrest is {user['liked_pages']}")
    print("\nPages information\n")
    for page in data ['pages']:
        print(f"{page['id']}:{page['name']}")

user_info(data)
# Out:
# User and their connection
#
# 1:Amit is friend with [2, 3] and their intrest is [101]
# 2:Priya is friend with [1, 4] and their intrest is [102]
# 3:Rahul is friend with [1] and their intrest is [101, 103]
# 4:Sara is friend with [2] and their intrest is [104]
#
# Pages information
#
# 101:Python Developers
# 102:Data Science Enthusiasts
# 103:AI & ML Community
# 104:Web Dev Hub
